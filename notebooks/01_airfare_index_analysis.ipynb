# %% [markdown]
# # AirFareX - Airfare Price Index & Forecasting Analysis
# Smart India Hackathon 2026 domestic airfare price index intelligence platform.

# %%
import pandas as pd
import numpy as np

# Load airfare index dataset
df_index = pd.read_csv('../backend/data/dashboard/airfare_index.csv')
df_index.head()
